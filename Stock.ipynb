# %%
## 상장법인목록 가져오기

import pandas as pd
krx_list = pd.read_html('상장법인목록.xls')
krx_list[0]

krx_list[0].종목코드 = krx_list[0].종목코드.map('{:06d}'.format)
krx_list[0]
# Out:
#             회사명    종목코드                        업종  \
# 0          라온테크  232680             특수 목적용 기계 제조업
# 1     삼성머스트스팩5호  380320                금융 지원 서비스업
# 2          엘비루셈  376190                   반도체 제조업
# 3        이성씨엔아이  379390  건축기술, 엔지니어링 및 관련 기술 서비스업
# 4       에이디엠코리아  187660           자연과학 및 공학 연구개발업
# ...         ...     ...                       ...
# 2443     CJ대한통운  000120                 도로 화물 운송업
# 2444      메리츠화재  000060                       보험업
# 2445         경방  000050                    종합 소매업
# 2446      유수홀딩스  000700       회사 본부 및 경영 컨설팅 서비스업
# 2447   한진중공업홀딩스  003480         연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0                                      반도체 및 FPD용 로봇시스템  2021-06-17  12월
# 1                                                기업인수합병  2021-06-17  12월
# 2                               디스플레이 구동 반도체(Driver IC)  2021-06-11  12월
# 3                                 원자력발전소 계측제어 서비스(경상정비)  2021-06-04  12월
# 4                                            임상 CRO 서비스  2021-06-03  12월
# ...                                                 ...         ...  ...
# 2443  Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02  12월
# 2444                                   손해보험(화재,해상,운송보험)  1956-07-02  12월
# 2445          섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월
# 2446                                               지주사업  1956-03-03  12월
# 2447                                               지주회사  1956-03-03  12월
#
#           대표자명                          홈페이지     지역
# 0          김원경     http://www.raonrobot.com/    경기도
# 1          임호원                           NaN  서울특별시
# 2          신현창       http://www.lblusem.com/   경상북도
# 3          박기선       http://www.iscni.co.kr/  부산광역시
# 4          김현우     http://www.admkorea.co.kr  서울특별시
# ...        ...                           ...    ...
# 2443       강신호    http://www.cjlogistics.com  서울특별시
# 2444       김용범     http://www.meritzfire.com  서울특별시
# 2445    김준, 김담    http://www.kyungbang.co.kr  서울특별시
# 2446       송영규  http://www.eusu-holdings.com  서울특별시
# 2447  조남호, 조원국  http://www.hhic-holdings.com    경기도
#
# [2448 rows x 9 columns]

# %%
lst = krx_list[0].sort_values(by='종목코드')
lst

## 종목코드만 뜯어내서 1년치 데이터를 DB에 넣는다?
# Out:
#              회사명    종목코드                      업종  \
# 2354        동화약품  000020                 의약품 제조업
# 2346       KR모터스  000040          그외 기타 운송장비 제조업
# 2445          경방  000050                  종합 소매업
# 2444       메리츠화재  000060                     보험업
# 2436       삼양홀딩스  000070                  기타 금융업
# ...          ...     ...                     ...
# 275          SNK  950180          소프트웨어 개발 및 공급업
# 113          미투젠  950190          소프트웨어 개발 및 공급업
# 135          소마젠  950200  그외 기타 전문, 과학 및 기술 서비스업
# 44    프레스티지바이오파마  950210         자연과학 및 공학 연구개발업
# 30         네오이뮨텍  950220         자연과학 및 공학 연구개발업
#
#                                            주요제품         상장일  결산월  \
# 2354                              의약품 제조,판매,수출입  1976-03-24  12월
# 2346                            이륜차(오토바이) 제조,도매  1976-05-25  12월
# 2445  섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월
# 2444                           손해보험(화재,해상,운송보험)  1956-07-02  12월
# 2436                               지주회사,경영자문컨설팅  1968-12-27  12월
# ...                                         ...         ...  ...
# 275                         IP 라이센스, 콘솔, 모바일 게임  2019-05-07  07월
# 113                              캐주얼게임, 소셜카지노게임  2020-08-18  12월
# 135                     유전체 분석 서비스 (NGS, CES 등)  2020-07-13  12월
# 44                            바이오시밀러 및 항체의약품 신약  2021-02-05  06월
# 30                                        면역항암제  2021-03-16  12월
#
#                    대표자명                              홈페이지     지역
# 2354                유준하         http://www.dong-wha.co.kr  서울특별시
# 2346                노성석           http://www.krmotors.com   경상남도
# 2445             김준, 김담        http://www.kyungbang.co.kr  서울특별시
# 2444                김용범         http://www.meritzfire.com  서울특별시
# 2436           엄태웅, 윤재엽            http://www.samyang.com  서울특별시
# ...                 ...                               ...    ...
# 275                 갈지휘         http://www.snk-corp.co.jp     일본
# 113           린즈웨이/라우호밍             http://www.me2zen.com     홍콩
# 135   Ryan W. Kim (김운봉)                               NaN     미국
# 44                  박소연  http://www.prestigebiopharma.com   싱가포르
# 30                  양세환        http://neoimmunetech.co.kr     미국
#
# [2448 rows x 9 columns]

# %%
import requests
import pandas as pd
import xmltodict
import json
import matplotlib.pyplot as plt

### stockcode = 삼성전자
### 미투젠
# krx_list[0].종목코드 
stockCode='361610'  ## SK IET


count='2400'
url = f'https://fchart.stock.naver.com/sise.nhn?symbol={stockCode}&timeframe=day&count={count}&requestType=0'

rs = requests.get(url)
dt = xmltodict.parse(rs.text)
js = json.dumps(dt,indent=4)
js = json.loads(js)

data = pd.json_normalize(js['protocol']['chartdata']['item'])
df = data['@data'].str.split('|',expand=True)
df.columns = ['Date','Open','High','Low','Close','Volume']
df
# Out:
#         Date    Open    High     Low   Close    Volume
# 0   20210511  210000  222500  154000  154500  11320278
# 1   20210512  152000  160000  141000  147500   4973674
# 2   20210513  145500  149500  142500  144000   1853703
# 3   20210514  146500  148000  140000  141000   1510892
# 4   20210517  142500  143000  138000  138000    931047
# 5   20210518  139000  146500  138500  144000   1474901
# 6   20210520  145000  146500  141000  142000    585820
# 7   20210521  144000  145000  142000  143500    468288
# 8   20210524  144500  145000  141000  142500    368061
# 9   20210525  143500  144000  141000  142000    300026
# 10  20210526  141000  142000  140500  141500    298091
# 11  20210527  141500  144500  141500  142000    298994
# 12  20210528  143000  146500  142000  145000    716415
# 13  20210531  145500  149000  145500  149000    628140
# 14  20210601  149500  151000  147500  150000    497546
# 15  20210602  151000  151000  147000  149500    397954
# 16  20210603  149500  150500  148000  149500    294278
# 17  20210604  149000  149500  147000  147500    276515
# 18  20210607  148000  148500  143000  143000    469107
# 19  20210608  142000  144000  141500  143000    243816
# 20  20210609  143000  143500  142000  142000    223769
# 21  20210610  142000  144500  141500  142500    493039
# 22  20210611  141500  157500  139500  157500   1458033
# 23  20210614  151500  153000  148000  148000    740629
# 24  20210615  149000  151500  148500  149500    417175
# 25  20210616  149000  153000  148000  152000    476285
# 26  20210617  151500  157000  150000  156000    648454
# 27  20210618  156500  159500  154500  158000    622211
# 28  20210621  156500  160500  155500  158500    431581
# 29  20210622  160000  160500  156000  159000    343775
# 30  20210623  159000  167500  157000  166500   1317043
# 31  20210624  167000  173500  165000  168500    907775
# 32  20210625  170500  175000  169500  172500    795885
# 33  20210628  174000  177000  166000  167000    702510
# 34  20210629  167500  173000  164000  173000    527489
# 35  20210630  173500  184000  173000  183000   1167597
# 36  20210701  182000  194500  179000  186500   1504043
# 37  20210702  189000  193000  183500  186000    648311
# 38  20210705  185000  188000  181500  185500    439884
# 39  20210706  185000  194000  185000  193000    666659
# 40  20210707  192500  199000  191500  199000    678190
# 41  20210708  200000  209500  199500  205000   1524306
# 42  20210709  205500  212000  195000  209000   1252883

# %%
## 시각화용 재료

dft = df.T
dft = dft.rename(columns=dft.iloc[0])
dft = dft.drop(dft.index[0])
dft= dft.T
dft.to_csv('미투젠.csv')
dftail = df.tail(30)
dftail['Close'] = dftail['Close'].astype('float')

plt.figure(figsize=(14,10))
plt.title('Graph')
plt.xticks(rotation=45)
plt.plot(dftail['Date'], dftail['Close'], 'co-')
plt.grid(color='gray', linestyle='--')
plt.show()
# Out:
# D:\folder\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
### 5영업일 전 등락률 폭이 15%이상인 경우 리스트에 등록할 수는 없는감?
## SK IET
